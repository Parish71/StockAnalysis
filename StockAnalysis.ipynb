# %% [markdown]
# <h2> Analise de Dados (yfinance) </h2>
#
# - **Automatizar um processo com a linguagem Python:**
#     - Instalar e utilizar bibliotecas
#     - Buscar dados de ações automaticamente
#     - Gerar algumas estatísticas com esses dados
#     - Gerar um gráfico simples de linha
#     - Automatizar o controle do teclado e mouse com o **pyautogui**
#     - Utilizar strings de múltiplas linhas
#     - Enviar e-mails de forma automática
#
#
# - **Envio de emails com Min Max e Cotação:**
#     - Você trabalha em uma empresa de investimentos e todos os dias precisa enviar um e-mail com o valor da cotação de algumas ações. O e-mail precisa conter as informações dos últimos seis meses:
#         - Cotação mínima da ação
#         - Cotação máxima da ação
#         - Cotação do dia

# %% [markdown]
# <h2 style="color: #37709F">Obtendo dados de ações de forma automática</h2>

# %% [markdown]
# <h3 style="color: #2F666F">Importando dados com yfinance </h3>
#
# - Site que fornece notícias sobre finanças, incluindo **cotações de ações**.
# - Link: [https://br.financas.yahoo.com/](https://br.financas.yahoo.com/)

# %% [markdown]
# <h4 style="color: #2F666F">Instalando as principais bibliotecas</h4>

# %%
# !pip install yfinance
# !pip install pyautogui
import yfinance
import pyautogui
# Out:
# Requirement already satisfied: yfinance in c:\users\rafae\anaconda3\lib\site-packages (0.2.21)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: requests>=2.26 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\rafae\anaconda3\lib\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rafae\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\rafae\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\rafae\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rafae\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\rafae\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rafae\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rafae\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rafae\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: pyautogui in c:\users\rafae\anaconda3\lib\site-packages (0.9.53)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\rafae\anaconda3\lib\site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: pymsgbox in c:\users\rafae\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: PyTweening>=1.0.1 in c:\users\rafae\anaconda3\lib\site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: mouseinfo in c:\users\rafae\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\rafae\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyrect in c:\users\rafae\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\rafae\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %% [markdown]
# <h3 style="color: #37709F">Buscando as cotações de uma Ação</h3>
#
# - **Ticker** é o código de uma ação.

# %%
ticker = input('Digite o código da ação: ')
dados = yfinance.Ticker(ticker)

# %%
dados.history()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-06-21 00:00:00-03:00  30.930000  32.000000  30.850000  31.850000
# 2023-06-22 00:00:00-03:00  31.459999  31.690001  31.080000  31.450001
# 2023-06-23 00:00:00-03:00  31.200001  31.280001  29.889999  30.160000
# 2023-06-26 00:00:00-03:00  30.120001  31.049999  30.120001  30.840000
# 2023-06-27 00:00:00-03:00  30.930000  31.200001  30.340000  30.600000
# 2023-06-28 00:00:00-03:00  30.580000  31.180000  30.549999  30.889999
# 2023-06-29 00:00:00-03:00  31.000000  31.120001  30.760000  31.030001
# 2023-06-30 00:00:00-03:00  31.000000  31.080000  29.320000  29.530001
plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# <h4 style="color: #2F666F">Gerando as estatísticas</h4>
#
# - Gerar estatísticas no Python é muito simples, pois já temos os métodos prontos para serem aplicados!
#
#
# - **cotação máxima:** max()
# - **votação mínima:** min()
# - **cotação atual:** é a última linha!Para acessá-la basta colocar [-1]

# %%
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]

print(maxima)
print(minima)
print(atual)
# Out:
# 31.850000381469727
# 19.03692054748535
# 29.68000030517578

# %% [markdown]
# <h3 style="color: #37709F">Enviando e-mail de forma automática</h3>
#
# - Processo de enviar um e-mail passo a passo:
#     - abra uma nova aba no navegador (clicar em + ou CTRL + T)
#     - digitar o endereço do gmail (www.gmail.com) e digitar ENTER
#     - clicar em **Escrever**
#     - digitar o endereço de e-mail do destinatário
#     - mudar para o campo Assunto (clicar no campo ou digitar tab)
#     - digitar o Assunto
#     - mudar para campo principal do e-mail (clicar no campo ou digitar tab)
#     - escrever a mensagem
#     - clicar em **Enviar**

# %% [markdown]
# <h4 style="color: #2F666F">Instalando as bibliotecas para auxiliar no envio do email</h4>

# %%
# !pip install pyperclip
import pyperclip
# Out:
# Requirement already satisfied: pyperclip in c:\users\rafae\anaconda3\lib\site-packages (1.8.2)

# %% [markdown]
# <h4 style="color: #2F666F">Criando o e-mail que vamos enviar</h4>

# %%
destinatario = "seuemail@gmail.com"
assunto = "Análise de Dados (yfinance)"

mensagem = f"""
Bom dia, teste de envio.

Segue abaixo as análises da ação {ticker} dos últimos seis meses:

Cotação máxima: R${round(maxima,2)}
Cotação mínima: R${round(minima,2)}
Cotação atual: R${round(atual,2)}

Atenciosamente,
Rafael Parish 
Analista de Dados
"""

# %%
print(destinatario)
print(assunto)
print(mensagem)
# Out:
# seuemail@gmail.com
# Análise de Dados (yfinance)
#
# Bom dia, teste de envio.
#
# Segue abaixo as análises da ação PETR4.SA dos últimos seis meses:
#
# Cotação máxima: R$31.85
# Cotação mínima: R$19.04
# Cotação atual: R$29.68
#
# Atenciosamente,
# Rafael Parish
# Analista de Dados

# %% [markdown]
# <h4 style="color: #2F666F">Automatizando o envio</h4>

# %%
# configurar uma pausa entre as ações do pyautogui
pyautogui.PAUSE = 3

# abrir uma nova aba
pyautogui.hotkey("ctrl", "t")

# copiar o endereço do gmail para o clipboard
pyperclip.copy("www.gmail.com")

# colar o endereço do gmail e dar um ENTER
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# clicando no botão Escrever (CORRIGIR)
pyautogui.click(x=2034, y=210)

# Preenchendo o destinatário
pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

# Preenchendo o assunto
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

# Preenchendo a mensagem
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

# Clicar no botão Enviar
pyautogui.click(x=3107, y=975)

# fechar a aba do gmail
pyautogui.hotkey("ctrl", "f4")

# Imprimir mensagem de enviado com sucesso
print('E-mail enviado com sucesso!')

# %% [markdown]
# <h4>Código para descobrir as coordenados do mouse</h4>

# %%
import time

time.sleep(5)
pyautogui.position()
